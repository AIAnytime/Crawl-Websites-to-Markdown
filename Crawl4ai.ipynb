# %%
# !pip install "crawl4ai @ git+https://github.com/unclecode/crawl4ai.git"
# Out:
# Collecting crawl4ai@ git+https://github.com/unclecode/crawl4ai.git
#   Cloning https://github.com/unclecode/crawl4ai.git to /tmp/pip-install-9z736bx0/crawl4ai_95adca0fa9d24ece88c9691a106b42d2
#   Running command git clone --filter=blob:none --quiet https://github.com/unclecode/crawl4ai.git /tmp/pip-install-9z736bx0/crawl4ai_95adca0fa9d24ece88c9691a106b42d2
#   Resolved https://github.com/unclecode/crawl4ai.git to commit e5e6a34e8097cb5ff72c026b19859b5b98246378
#   Preparing metadata (setup.py) ... done
# Collecting aiohttp==3.9.5 (from crawl4ai@ git+https://github.com/unclecode/crawl4ai.git)
#   Downloading aiohttp-3.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.5 kB)
# Collecting aiosqlite==0.20.0 (from crawl4ai@ git+https://github.com/unclecode/crawl4ai.git)
#   Downloading aiosqlite-0.20.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: beautifulsoup4==4.12.3 in /usr/local/lib/python3.10/dist-packages (from crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (4.12.3)
# Collecting fastapi==0.111.0 (from crawl4ai@ git+https://github.com/unclecode/crawl4ai.git)
#   Downloading fastapi-0.111.0-py3-none-any.whl.metadata (25 kB)
# Collecting html2text==2024.2.26 (from crawl4ai@ git+https://github.com/unclecode/crawl4ai.git)
#   Downloading html2text-2024.2.26.tar.gz (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 kB 2.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting httpx==0.27.0 (from crawl4ai@ git+https://github.com/unclecode/crawl4ai.git)
#   Downloading httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting litellm==1.40.17 (from crawl4ai@ git+https://github.com/unclecode/crawl4ai.git)
#   Downloading litellm-1.40.17-py3-none-any.whl.metadata (30 kB)
# Collecting pydantic==2.7.4 (from crawl4ai@ git+https://github.com/unclecode/crawl4ai.git)
#   Downloading pydantic-2.7.4-py3-none-any.whl.metadata (109 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.4/109.4 kB 623.2 kB/s eta 0:00:00
# Collecting python-dotenv==1.0.1 (from crawl4ai@ git+https://github.com/unclecode/crawl4ai.git)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: requests==2.32.3 in /usr/local/lib/python3.10/dist-packages (from crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (2.32.3)
# Collecting rich==13.7.1 (from crawl4ai@ git+https://github.com/unclecode/crawl4ai.git)
#   Downloading rich-13.7.1-py3-none-any.whl.metadata (18 kB)
# Collecting selenium==4.23.1 (from crawl4ai@ git+https://github.com/unclecode/crawl4ai.git)
#   Downloading selenium-4.23.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting uvicorn==0.30.1 (from crawl4ai@ git+https://github.com/unclecode/crawl4ai.git)
#   Downloading uvicorn-0.30.1-py3-none-any.whl.metadata (6.3 kB)
# Collecting pillow==10.3.0 (from crawl4ai@ git+https://github.com/unclecode/crawl4ai.git)
#   Downloading pillow-10.3.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Collecting slowapi==0.1.9 (from crawl4ai@ git+https://github.com/unclecode/crawl4ai.git)
#   Downloading slowapi-0.1.9-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.9.5->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.9.5->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.9.5->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.9.5->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.9.5->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.9.5->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (4.0.3)
# Requirement already satisfied: typing_extensions>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiosqlite==0.20.0->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4==4.12.3->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (2.6)
# Collecting starlette<0.38.0,>=0.37.2 (from fastapi==0.111.0->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git)
#   Downloading starlette-0.37.2-py3-none-any.whl.metadata (5.9 kB)
# Collecting fastapi-cli>=0.0.2 (from fastapi==0.111.0->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git)
#   Downloading fastapi_cli-0.0.5-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: jinja2>=2.11.2 in /usr/local/lib/python3.10/dist-packages (from fastapi==0.111.0->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (3.1.4)
# Collecting python-multipart>=0.0.7 (from fastapi==0.111.0->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git)
#   Downloading python_multipart-0.0.9-py3-none-any.whl.metadata (2.5 kB)
# Collecting ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 (from fastapi==0.111.0->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git)
#   Downloading ujson-5.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.3 kB)
# Collecting orjson>=3.2.1 (from fastapi==0.111.0->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git)
#   Downloading orjson-3.10.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 3.3 MB/s eta 0:00:00
# Collecting email_validator>=2.0.0 (from fastapi==0.111.0->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git)
#   Downloading email_validator-2.2.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx==0.27.0->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx==0.27.0->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (2024.8.30)
# Collecting httpcore==1.* (from httpx==0.27.0->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx==0.27.0->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (3.8)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx==0.27.0->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (1.3.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from litellm==1.40.17->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (8.1.7)
# Collecting ijson (from litellm==1.40.17->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git)
#   Downloading ijson-3.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (21 kB)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /usr/local/lib/python3.10/dist-packages (from litellm==1.40.17->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (8.4.0)
# Collecting openai>=1.27.0 (from litellm==1.40.17->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git)
#   Downloading openai-1.44.0-py3-none-any.whl.metadata (22 kB)
# Collecting tiktoken>=0.7.0 (from litellm==1.40.17->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git)
#   Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.10/dist-packages (from litellm==1.40.17->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (0.19.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic==2.7.4->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (0.7.0)
# Collecting pydantic-core==2.18.4 (from pydantic==2.7.4->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git)
#   Downloading pydantic_core-2.18.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.5 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests==2.32.3->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests==2.32.3->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (2.0.7)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich==13.7.1->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich==13.7.1->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (2.16.1)
# Collecting trio~=0.17 (from selenium==4.23.1->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git)
#   Downloading trio-0.26.2-py3-none-any.whl.metadata (8.6 kB)
# Collecting trio-websocket~=0.9 (from selenium==4.23.1->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git)
#   Downloading trio_websocket-0.11.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: websocket-client~=1.8 in /usr/local/lib/python3.10/dist-packages (from selenium==4.23.1->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (1.8.0)
# Collecting limits>=2.3 (from slowapi==0.1.9->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git)
#   Downloading limits-3.13.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting h11>=0.8 (from uvicorn==0.30.1->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting dnspython>=2.0.0 (from email_validator>=2.0.0->fastapi==0.111.0->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git)
#   Downloading dnspython-2.6.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: typer>=0.12.3 in /usr/local/lib/python3.10/dist-packages (from fastapi-cli>=0.0.2->fastapi==0.111.0->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (0.12.5)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=6.8.0->litellm==1.40.17->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (3.20.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.11.2->fastapi==0.111.0->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (2.1.5)
# Collecting deprecated>=1.2 (from limits>=2.3->slowapi==0.1.9->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: importlib-resources>=1.3 in /usr/local/lib/python3.10/dist-packages (from limits>=2.3->slowapi==0.1.9->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (6.4.4)
# Requirement already satisfied: packaging<25,>=21 in /usr/local/lib/python3.10/dist-packages (from limits>=2.3->slowapi==0.1.9->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (24.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich==13.7.1->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (0.1.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai>=1.27.0->litellm==1.40.17->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (1.7.0)
# Collecting jiter<1,>=0.4.0 (from openai>=1.27.0->litellm==1.40.17->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git)
#   Downloading jiter-0.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai>=1.27.0->litellm==1.40.17->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (4.66.5)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx==0.27.0->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (1.2.2)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken>=0.7.0->litellm==1.40.17->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (2024.5.15)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium==4.23.1->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (2.4.0)
# Collecting outcome (from trio~=0.17->selenium==4.23.1->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium==4.23.1->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git)
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from urllib3[socks]<3,>=1.26->selenium==4.23.1->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (1.7.1)
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.12.0->fastapi==0.111.0->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git)
#   Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.12.0->fastapi==0.111.0->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (6.0.2)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.12.0->fastapi==0.111.0->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git)
#   Downloading uvloop-0.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.12.0->fastapi==0.111.0->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git)
#   Downloading watchfiles-0.24.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.12.0->fastapi==0.111.0->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git)
#   Downloading websockets-13.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from tokenizers->litellm==1.40.17->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (0.24.6)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated>=1.2->limits>=2.3->slowapi==0.1.9->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (1.16.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm==1.40.17->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm==1.40.17->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (2024.6.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi==0.111.0->crawl4ai@ git+https://github.com/unclecode/crawl4ai.git) (1.5.4)
# Downloading aiohttp-3.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 29.0 MB/s eta 0:00:00
# Downloading aiosqlite-0.20.0-py3-none-any.whl (15 kB)
# Downloading fastapi-0.111.0-py3-none-any.whl (91 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 7.1 MB/s eta 0:00:00
# Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 4.3 MB/s eta 0:00:00
# Downloading litellm-1.40.17-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 53.1 MB/s eta 0:00:00
# Downloading pillow-10.3.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 50.8 MB/s eta 0:00:00
# Downloading pydantic-2.7.4-py3-none-any.whl (409 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.0/409.0 kB 18.7 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading rich-13.7.1-py3-none-any.whl (240 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.7/240.7 kB 13.5 MB/s eta 0:00:00
# Downloading selenium-4.23.1-py3-none-any.whl (9.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 51.4 MB/s eta 0:00:00
# Downloading slowapi-0.1.9-py3-none-any.whl (14 kB)
# Downloading uvicorn-0.30.1-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 4.1 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 5.6 MB/s eta 0:00:00
# Downloading pydantic_core-2.18.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 39.0 MB/s eta 0:00:00
# Downloading email_validator-2.2.0-py3-none-any.whl (33 kB)
# Downloading fastapi_cli-0.0.5-py3-none-any.whl (9.5 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.5 MB/s eta 0:00:00
# Downloading limits-3.13.0-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 3.3 MB/s eta 0:00:00
# Downloading openai-1.44.0-py3-none-any.whl (367 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 367.8/367.8 kB 23.7 MB/s eta 0:00:00
# Downloading orjson-3.10.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 10.0 MB/s eta 0:00:00
# Downloading python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Downloading starlette-0.37.2-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 4.8 MB/s eta 0:00:00
# Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 37.0 MB/s eta 0:00:00
# Downloading trio-0.26.2-py3-none-any.whl (475 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 476.0/476.0 kB 28.3 MB/s eta 0:00:00
# Downloading trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Downloading ujson-5.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 3.2 MB/s eta 0:00:00
# Downloading ijson-3.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 7.5 MB/s eta 0:00:00
# Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 19.0 MB/s eta 0:00:00
# Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (341 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 20.9 MB/s eta 0:00:00
# Downloading jiter-0.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (318 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 20.9 MB/s eta 0:00:00
# Downloading uvloop-0.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 67.4 MB/s eta 0:00:00
# Downloading watchfiles-0.24.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (425 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 425.7/425.7 kB 22.5 MB/s eta 0:00:00
# Downloading websockets-13.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (157 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.3/157.3 kB 9.5 MB/s eta 0:00:00
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Building wheels for collected packages: crawl4ai, html2text
#   Building wheel for crawl4ai (setup.py) ... done
#   Created wheel for crawl4ai: filename=Crawl4AI-0.2.77-py3-none-any.whl size=47936 sha256=68a22f6742f978ce8d3726f1a5050821f75cbe3c8a232033f92c8c0b91a7fc41
#   Stored in directory: /tmp/pip-ephem-wheel-cache-l_k1lpkm/wheels/99/72/3b/2fedf5c14c27671cb743e96a3af3f438545902bf19a3e5823f
#   Building wheel for html2text (setup.py) ... done
#   Created wheel for html2text: filename=html2text-2024.2.26-py3-none-any.whl size=33111 sha256=7fea630022d71adc3c75d1c98076f10b2ff1ac4d0536d8586a00b5e29b678020
#   Stored in directory: /root/.cache/pip/wheels/f3/96/6d/a7eba8f80d31cbd188a2787b81514d82fc5ae6943c44777659
# Successfully built crawl4ai html2text
# Installing collected packages: ijson, websockets, uvloop, ujson, python-multipart, python-dotenv, pydantic-core, pillow, outcome, orjson, jiter, httptools, html2text, h11, dnspython, deprecated, aiosqlite, wsproto, watchfiles, uvicorn, trio, tiktoken, starlette, rich, pydantic, limits, httpcore, email_validator, aiohttp, trio-websocket, slowapi, httpx, selenium, openai, fastapi-cli, litellm, fastapi, crawl4ai
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.20.1
#     Uninstalling pydantic_core-2.20.1:
#       Successfully uninstalled pydantic_core-2.20.1
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
#   Attempting uninstall: rich
#     Found existing installation: rich 13.8.0
#     Uninstalling rich-13.8.0:
#       Successfully uninstalled rich-13.8.0
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.8.2
#     Uninstalling pydantic-2.8.2:
#       Successfully uninstalled pydantic-2.8.2
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.10.5
#     Uninstalling aiohttp-3.10.5:
#       Successfully uninstalled aiohttp-3.10.5
# Successfully installed aiohttp-3.9.5 aiosqlite-0.20.0 crawl4ai-0.2.77 deprecated-1.2.14 dnspython-2.6.1 email_validator-2.2.0 fastapi-0.111.0 fastapi-cli-0.0.5 h11-0.14.0 html2text-2024.2.26 httpcore-1.0.5 httptools-0.6.1 httpx-0.27.0 ijson-3.3.0 jiter-0.5.0 limits-3.13.0 litellm-1.40.17 openai-1.44.0 orjson-3.10.7 outcome-1.3.0.post0 pillow-10.3.0 pydantic-2.7.4 pydantic-core-2.18.4 python-dotenv-1.0.1 python-multipart-0.0.9 rich-13.7.1 selenium-4.23.1 slowapi-0.1.9 starlette-0.37.2 tiktoken-0.7.0 trio-0.26.2 trio-websocket-0.11.1 ujson-5.10.0 uvicorn-0.30.1 uvloop-0.20.0 watchfiles-0.24.0 websockets-13.0.1 wsproto-1.2.0

# %%
from crawl4ai import WebCrawler

# %%
# Create an instance of WebCrawler
crawler = WebCrawler()
# Out:
# [LOG] 🚀 Initializing LocalSeleniumCrawlerStrategy

# %%
# Warm up the crawler (load necessary models)
crawler.warmup()
# Out:
# [LOG] 🌤️  Warming up the WebCrawler
# [LOG] 🌞 WebCrawler is ready to crawl

# %%
# Run the crawler on a URL
result = crawler.run(
    url = "https://www.eu-startups.com/directory/"
)

# Print the extracted content
print(result.markdown)
# Out:
# [LOG] 🚀 Crawling done for https://www.eu-startups.com/directory/, success: True, time taken: 10.05967903137207 seconds
# [LOG] 🚀 Content extracted for https://www.eu-startups.com/directory/, success: True, time taken: 0.36144351959228516 seconds
# [LOG] 🔥 Extracting semantic blocks for https://www.eu-startups.com/directory/, Strategy: NoExtractionStrategy
# [LOG] 🚀 Extraction done for https://www.eu-startups.com/directory/, time taken: 0.3694131374359131 seconds.
# Join 81,000 Founders & Investors who already receive our weekly EU-Startups
# Newsletter!
#
# COUNT ME IN
#
# No, Thanks
#
# Sign in
#
#   * Magazine
#     * Interviews
#     * Re-/Launch
#     * Funding
#     * Acquisitions
#     * Other Stuff
#     * Know-How
#   * Summit
#     * Event Overview
#     * Get Tickets
#     * Sponsor
#     * Exhibit
#   * Job Board
#     * Job Board
#     * Post a Job
#   * Insights
#     * Startup Sourcing
#     * Premium Reports
#     * Podcast
#   * Database
#     * Startup Database
#     * Investor Database
#   * About us
#     * Mission / Team
#     * Advertising
#     * Our Newsletter
#   * –CLUB–
#     * Register Now
#     * Log In
#     * CLUB Benefits
#
# __
#
# Sign in
#
# Welcome!Log into your account
#
# your username
#
# your password
#
# Forgot your password?
#
# Password recovery
#
# Recover your password
#
# your email
#
# Search
#
# ![](\\"https://www.eu-startups.com/wp-content/uploads/2024/08/1-3.png\\"/)
#
# ![\\"Logo\\"](\\"https://www.eu-startups.com/wp-
# content/uploads/2023/02/EU_Startups_Logo_Transparent_White-1.png\\")
#
# ![\\"Logo\\"](\\"https://www.eu-startups.com/wp-
# content/uploads/2023/02/EU_Startups_Logo_Transparent_White-1.png\\")
#
# ![\\"Logo\\"](\\"https://www.eu-startups.com/wp-content/uploads/2022/08/EU-
# Startups-Logo.png\\")
#
# ![](\\"https://www.eu-startups.com/wp-content/uploads/2024/08/1-3.png\\"/)
#
#   * Magazine
#
#     * Interviews
#
#     * Re-/Launch
#
#     * Funding
#
#     * Acquisitions
#
#     * Other Stuff
#
#     * Know-How
#
#   * Summit
#
#     * Event Overview
#
#     * Get Tickets
#
#     * Sponsor
#
#     * Exhibit
#
#   * Job Board
#
#     * Job Board
#
#     * Post a Job
#
#   * Insights
#
#     * Startup Sourcing
#
#     * Premium Reports
#
#     * Podcast
#
#   * Database
#
#     * Startup Database
#
#     * Investor Database
#
#   * About us
#
#     * Mission / Team
#
#     * Advertising
#
#     * Our Newsletter
#
#   * –CLUB–
#
#     * Register Now
#
#     * Log In
#
#     * CLUB Benefits
#
# Search
#
# ![\\"Logo\\"](\\"https://www.eu-startups.com/wp-content/uploads/2022/08/EU-
# Startups-Logo.png\\")
#
#   * Magazine
#
#     * Interviews
#
#     * Re-/Launch
#
#     * Funding
#
#     * Acquisitions
#
#     * Other Stuff
#
#     * Know-How
#
#   * Summit
#
#     * Event Overview
#
#     * Get Tickets
#
#     * Sponsor
#
#     * Exhibit
#
#   * Job Board
#
#     * Job Board
#
#     * Post a Job
#
#   * Insights
#
#     * Startup Sourcing
#
#     * Premium Reports
#
#     * Podcast
#
#   * Database
#
#     * Startup Database
#
#     * Investor Database
#
#   * About us
#
#     * Mission / Team
#
#     * Advertising
#
#     * Our Newsletter
#
#   * –CLUB–
#
#     * Register Now
#
#     * Log In
#
#     * CLUB Benefits
#
# Search
#
# Home Startup Database
#
# #  Startup Database
#
# Keywords:
#
# Advanced Search
#
# Add Listing
#
# Sorted by Country:
#
#   * Austria (723)
#   * Belgium (662)
#   * Bulgaria (243)
#   * Croatia (198)
#   * Cyprus (271)
#   * Czechia (299)
#   * Denmark (756)
#   * Estonia (722)
#   * Finland (564)
#   * France (2835)
#   * Germany (4398)
#   * Greece (276)
#   * Hungary (315)
#   * Ireland (825)
#   * Italy (1414)
#   * Latvia (242)
#   * Lithuania (275)
#   * Luxembourg (214)
#   * Malta (146)
#   * Netherlands (1762)
#   * Norway (515)
#   * Poland (699)
#   * Portugal (589)
#   * Romania (385)
#   * Slovakia (162)
#   * Slovenia (201)
#   * Spain (2653)
#   * Sweden (1028)
#   * Switzerland (1068)
#   * UK (6726)
#
# Sort By:Default Business Name Total Funding Founded
#
# ### Infrafon GmbH
#
# ![\\"Infrafon](\\"https://www.eu-startups.com/wp-
# content/uploads/2024/09/dmea-150x174.jpg\\")
#
# Business Name:
#
# Infrafon GmbH
#
# Category:
#
# Germany
#
# Based in:
#
# Freiburg
#
# Tags:
#
# edge Digitalization, Security, Workmanagement
#
# Founded:
#
# 2021
#
# ### Cimphony
#
# ![\\"Cimphony\\"](\\"https://www.eu-startups.com/wp-
# content/uploads/2024/09/agNsxwT_400x400-150x150.jpg\\")
#
# Business Name:
#
# Cimphony
#
# Category:
#
# Austria
#
# Based in:
#
# Thal
#
# Tags:
#
# SaaS, AI,Bussines
#
# Founded:
#
# 2024
#
# ### Phi Wallet
#
# ![\\"Phi](\\"https://www.eu-startups.com/wp-
# content/uploads/2024/09/Screenshot-2024-09-03-at-12.31.24-150x88.png\\")
#
# Business Name:
#
# Phi Wallet
#
# Category:
#
# Portugal
#
# Based in:
#
# Lisbon
#
# Tags:
#
# Financial Services
#
# Founded:
#
# 2021
#
# ### Calensync.live
#
# ![\\"Calensync.live\\"](\\"https://www.eu-startups.com/wp-
# content/uploads/2024/09/calensync_226548.png\\")
#
# Business Name:
#
# Calensync.live
#
# Category:
#
# Estonia
#
# Based in:
#
# Tallinn, Estonia
#
# Tags:
#
# Entrepreneurs, freelancers, directors, contractors
#
# Founded:
#
# 2023
#
# ### VidToBlogs
#
# ![\\"VidToBlogs\\"](\\"https://www.eu-startups.com/wp-
# content/uploads/2024/09/mfQq88js-150x84.jpg\\")
#
# Business Name:
#
# VidToBlogs
#
# Category:
#
# Estonia
#
# Based in:
#
# Tallinn
#
# Tags:
#
# Video, Blog, Text Generation,
#
# Founded:
#
# 2024
#
# ### WAPlus – WhatsApp CRM
#
# ![\\"WhatsApp](\\"https://www.eu-startups.com/wp-
# content/uploads/2024/09/logo-1-150x150.png\\")
#
# Business Name:
#
# WAPlus – WhatsApp CRM
#
# Category:
#
# Spain
#
# Based in:
#
# Barcelona
#
# Tags:
#
# Schedule Message, Auto Reply, CRM Integration, AI ChatBot, AI Translator
#
# Founded:
#
# 2022
#
# ### Bricks
#
# ![\\"Bricks\\"](\\"https://www.eu-startups.com/wp-
# content/uploads/2024/09/bricks-og-image-150x79.png\\")
#
# Business Name:
#
# Bricks
#
# Category:
#
# UK
#
# Based in:
#
# London
#
# Tags:
#
# productivity, collaboration tools, spreadsheets, presentations, slide decks,
# docs, wiki
#
# Founded:
#
# 2024
#
# ### Ask Bart
#
# ![\\"Ask](\\"https://www.eu-startups.com/wp-content/uploads/2024/09/Askbart-
# rectangular-logo-150x39.png\\")
#
# Business Name:
#
# Ask Bart
#
# Category:
#
# UK
#
# Based in:
#
# Worthing
#
# Tags:
#
# care homes, health care
#
# Founded:
#
# 2024
#
# ### Emble
#
# ![\\"Emble\\"](\\"https://www.eu-startups.com/wp-
# content/uploads/2024/09/Emble-avatar-white-on-black-solid_-150x150.png\\")
#
# Business Name:
#
# Emble
#
# Category:
#
# UK
#
# Based in:
#
# London, United Kingdom
#
# Tags:
#
# User Research, User Testing, Product Management, SaaS Tools,
#
# Founded:
#
# 2024
#
# ### TinkTide
#
# ![\\"TinkTide\\"](\\"https://www.eu-startups.com/wp-
# content/uploads/2024/09/workflow4-150x83.png\\")
#
# Business Name:
#
# TinkTide
#
# Category:
#
# Croatia
#
# Based in:
#
# Zagreb
#
# Tags:
#
# entrepreneur, small business, startup, market research, business idea,
# business plan, pitch deck
#
# Founded:
#
# 2024
#
# ### Tatanka.nl
#
# ![\\"Tatanka.nl\\"](\\"https://www.eu-startups.com/wp-
# content/uploads/2024/09/logo-150x150.png\\")
#
# Business Name:
#
# Tatanka.nl
#
# Category:
#
# Netherlands
#
# Based in:
#
# Amsterdam
#
# Tags:
#
# natural supplements, herbal supplements, mood enhancers, energy boosters,
# relaxation aids, responsible use
#
# Founded:
#
# 2023
#
# Next →
#
# #### STARTUP NEWS – By Country
#
#   * ![](\\"/wp-content/uploads/icons/Austria-Startups.png\\"/)Austria
#   * ![](\\"/wp-content/uploads/icons/Belgium-Startups.png\\"/)Belgium
#   * ![](\\"/wp-content/uploads/icons/Bulgaria-Startups.png\\"/)Bulgaria
#   * ![](\\"/wp-content/uploads/icons/Croatia-Startups.png\\"/)Croatia
#   * ![](\\"/wp-content/uploads/icons/Cyprus-Startups.png\\"/)Cyprus
#   * ![](\\"/wp-content/uploads/icons/Czechia-Startups.png\\"/)Czechia
#   * ![](\\"/wp-content/uploads/icons/Denmark-Startups.png\\"/)Denmark
#   * ![](\\"/wp-content/uploads/icons/Estonia-Startups.png\\"/)Estonia
#   * ![](\\"/wp-content/uploads/icons/Finland-Startups.png\\"/)Finland
#   * ![](\\"/wp-content/uploads/icons/France-Startups.png\\"/)France
#   * ![](\\"/wp-content/uploads/icons/Germany-Startups.png\\"/)Germany
#   * ![](\\"/wp-content/uploads/icons/Greece-Startups.png\\"/)Greece
#   * ![](\\"/wp-content/uploads/icons/Hungary-Startups.png\\"/)Hungary
#   * ![](\\"/wp-content/uploads/icons/Ireland-Startups.png\\"/)Ireland
#   * ![](\\"/wp-content/uploads/icons/Italy-Startups.png\\"/)Italy
#   * ![](\\"/wp-content/uploads/icons/Latvia-Startups.png\\"/)Latvia
#   * ![](\\"/wp-content/uploads/icons/Lithuania-Startups.png\\"/)Lithuania
#   * ![](\\"/wp-content/uploads/icons/Luxembourg-Startups.png\\"/)Luxembourg
#   * ![](\\"/wp-content/uploads/icons/Malta-Startups.png\\"/)Malta
#   * ![](\\"/wp-content/uploads/icons/Netherlands-Startups.png\\"/)Netherlands
#   * ![](\\"/wp-content/uploads/icons/Norway-Startups.png\\"/)Norway
#   * ![](\\"/wp-content/uploads/icons/Poland-Startups.png\\"/)Poland
#   * ![](\\"/wp-content/uploads/icons/Portugal-Startups.png\\"/)Portugal
#   * ![](\\"/wp-content/uploads/icons/Romania-Startups.png\\"/)Romania
#   * ![](\\"/wp-content/uploads/icons/Slovakia-Startups.png\\"/)Slovakia
#   * ![](\\"/wp-content/uploads/icons/Slovenia-Startups.png\\"/)Slovenia
#   * ![](\\"/wp-content/uploads/icons/Spain-Startups.png\\"/)Spain
#   * ![](\\"/wp-content/uploads/icons/Sweden-Startups.png\\"/)Sweden
#   * ![](\\"/wp-content/uploads/icons/Switzerland-Startups.png\\"/)Switzerland
#   * ![](\\"/wp-content/uploads/icons/UK-Startups.png\\"/)UK
#
# #### Receive our weekly Newsletter
#
# Newsletter Form (#1)
#
# First Name
#
# Email
#
# Subscribe Now
#
# #### Our Channels
#
# ![](\\"https://www.eu-startups.com/wp-
# content/uploads/2024/06/LinkedIn-2.png\\"/) ![](\\"https://www.eu-
# startups.com/wp-
# content/uploads/2024/06/Facebook-1-1.png\\"/)![](\\"https://www.eu-
# startups.com/wp-
# content/uploads/2024/06/Instagram-1.png\\"/)![](\\"https://www.eu-
# startups.com/wp-
# content/uploads/2024/06/Newsletter-1.png\\"/)![](\\"https://www.eu-
# startups.com/wp-content/uploads/2024/06/Twitter-1.png\\"/)
#
# #### Latest Jobs
#
# Event Manager Barcelona, Spain
#
# Data Engineer Watermael-Boitsfort, Belgium
#
# Innovatie Manager Amsterdam, Netherlands
#
# Traineeship Pensions Rotterdam, Netherlands
#
# Field Sales Representative Zürich, Switzerland
#
# View All
#
# #### Advertising
#
# ![](\\"https://www.eu-startups.com/wp-content/uploads/2023/05/Sourcing-
# square.png\\"/)
#
# ![\\"Logo\\"](\\"https://www.eu-startups.com/wp-
# content/uploads/2023/02/EU_Startups_Logo_Transparent_White-1.png\\")
#
# ### ABOUT US
#
# EU-Startups.com is the leading online magazine about startups in Europe. Learn
# more about us and our advertising options.
#
# ### FOLLOW US
#
# Facebook
#
# Instagram
#
# Linkedin
#
# RSS
#
# Twitter
#
# © Menlo Media S.L. - All rights reserved.
#
# Notifications
